# %%
# Import several packages that will be used throughout

# numeric packages
import numpy as np
import scipy
import scipy.io
import pandas as pd

import h5py
import cPickle as pickle
import gzip

# filesystem and OS
import sys, os, time
import glob

# plotting
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid", {'axes.grid' : False})
from IPython.display import clear_output

import warnings
warnings.filterwarnings('ignore')

import keras
from keras import backend as K

sys.path.append("/home/adalbert/nbserver/satsense/keras-utils/")
sys.path.append("/home/adalbert/nbserver/satsense/keras-models/")
sys.path.append("/home/adalbert/nbserver/keras/keras/utils/")

import keras_utils as ku
from multi_gpu import make_parallel

# these magics ensure that external modules that are modified are also automatically reloaded
# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %%
workdir = "/home/adalbert/nbserver/tf-workspace/urban-atlas-experiments/"

if not os.path.exists(workdir):
    os.makedirs(workdir)
    
os.chdir(workdir)

# %%
all_classes = '''Agricultural + Semi-natural areas + Wetlands
Airports
Construction sites
Continuous Urban Fabric (S.L. > 80%)
Discontinuous Dense Urban Fabric (S.L. : 50% -  80%)
Discontinuous Low Density Urban Fabric (S.L. : 10% - 30%)
Discontinuous Medium Density Urban Fabric (S.L. : 30% - 50%)
Discontinuous Very Low Density Urban Fabric (S.L. < 10%)
Fast transit roads and associated land
Forests
Green urban areas
Industrial, commercial, public, military and private units
Isolated Structures
Land without current use
Mineral extraction and dump sites
Other roads and associated land
Port areas
Railways and associated land
Sports and leisure facilities
Water bodies'''.split("\n")

classes = all_classes
print len(classes)

class2label = {c:i for i,c in enumerate(classes)}
label2class = {i:c for i,c in enumerate(classes)}
class_weights = {c:1 for c in label2class.keys()}

N_CLASSES = len(classes)

# list of cities to study

all_cities = ["bucuresti", "berlin", "barcelona", "paris", "athina", \
              "firenze", "dublin", "london", "tallinn", "bremen"]
# Out:
# 20

# %% [markdown]
# # Set up data sources

# %%
train_dir = "/home/adalbert/data/urban-atlas/extracted-data/"

# %%
def load_data_sources(cities):

    # load paths to source images

    files = np.array([f for c in cities for f in glob.glob(train_dir + "%s/img/*/*.jpg"%c)])
    files_df =  pd.DataFrame(files).rename(columns={0:"filename"})
    files_df['class'] = files_df['filename'].apply(lambda x: x.split("/")[-2])
    files_df['city'] = files_df['filename'].apply(lambda x: x.split("/")[-4])
    files_df['phase'] = files_df['filename'].apply(lambda x: "validation" if "grid" in x else "training")

    # consolidate classes to work with

    consolidate_classes = {
        "Continuous Urban Fabric (S.L. > 80%)":"High Density Urban Fabric",
         "Discontinuous Dense Urban Fabric (S.L. : 50% -  80%)":"High Density Urban Fabric",
         "Discontinuous Medium Density Urban Fabric (S.L. : 30% - 50%)":"Low Density Urban Fabric",
         "Discontinuous Low Density Urban Fabric (S.L. : 10% - 30%)":"Low Density Urban Fabric",
         "Discontinuous Very Low Density Urban Fabric (S.L. < 10%)":"Low Density Urban Fabric"
    }
    files_df['class'] = files_df['class'].apply(
        lambda x: consolidate_classes[x] if x in consolidate_classes else x)

    # TODO!!!
    # there is a bug here -- the high density urban fabric is not included (because of the 'continuous' below)!!
    # another bug: medium density does not exist!
    include_classes = ["Green urban areas", 
                       "Airports",
                       "Forests",
                       "Agricultural + Semi-natural areas + Wetlands",
                       # "Railways and associated land",
                       "Continuous High Density Urban Fabric", # BUG HERE!!!!! ('Continuous' should be removed)
                        #"Mineral extraction and dump sites",
                       "Fast transit roads and associated land",
                       "Medium Density Urban Fabric", # BUG HERE!!!!! (No 'Medium' class consolidated above!)
                       "Low Density Urban Fabric",
                       "Other roads and associated land",
                       "Water bodies",
                       "Sports and leisure facilities",
                       "Industrial, commercial, public, military and private units"]
    files_df = files_df[files_df['class'].isin(include_classes)]

    return files_df

# %%
cities = ["athina", "berlin", "bucuresti", "tallinn", "barcelona", "dublin"]

files_df = load_data_sources(cities)

# update classes dictionary if needed

classes = files_df['class'].unique()
classes.sort()
class2label = {c:i for i,c in enumerate(classes)}
label2class = {i:c for i,c in enumerate(classes)}
N_CLASSES = len(classes)
print N_CLASSES

with gzip.open("classes.pickle.gz", "w") as f:
    pickle.dump({"class2label":class2label, "label2class":label2class}, f)

# class_weights = get_class_weights(files_df['class'].apply(lambda x: class2label[x]))
class_weights = {i:1 for i in range(N_CLASSES)}
# Out:
# 10

# %%
stats_train = pd.DataFrame(files_df[files_df.phase=="training"].groupby(["city", "class"]).apply(len))\
                    .reset_index()\
                    .rename(columns={0:"count"})
stats_train = stats_train.pivot(columns="city", index="class")
stats_train = stats_train.fillna(0).astype(int)
stats_train.columns = stats_train.columns.droplevel(0)
# add in row and column total sums
stats_train['class total'] = stats_train.sum(1)
newidx = stats_train.index.values.tolist() + ["city total"]
stats_train = stats_train.append(stats_train.sum(0), ignore_index=True)
stats_train.index = newidx

stats_train.to_latex("samples_stats_train.tex")

stats_valid = pd.DataFrame(files_df[files_df.phase=="validation"].groupby(["city", "class"]).apply(len))\
                    .reset_index()\
                    .rename(columns={0:"count"})
stats_valid = stats_valid.pivot(columns="city", index="class")
stats_valid = stats_valid.fillna(0).astype(int)
stats_valid.columns = stats_valid.columns.droplevel(0)
# add in row and column total sums
stats_valid['total-class'] = stats_valid.sum(1)
newidx = stats_valid.index.values.tolist() + ["total-city"]
stats_valid = stats_valid.append(stats_valid.sum(0), ignore_index=True)
stats_valid.index = newidx

stats_valid.to_latex("samples_stats_valid.tex")

# %%
stats_train
# Out:
# city                                                athina  barcelona  berlin  \
# Agricultural + Semi-natural areas + Wetlands          4347       2987    7602
# Airports                                               382        452     232
# Fast transit roads and associated land                 328        928    1226
# Forests                                               1806       2438    7397
# Green urban areas                                      990        722    1840
# Industrial, commercial, public, military and pr...    1887       2116    4761
# Low Density Urban Fabric                              3568       2648    8268
# Other roads and associated land                       1272       1326    1439
# Sports and leisure facilities                          750       1185    2268
# Water bodies                                           537        408    1919
# city total                                           15867      15210   36952
#
# city                                                bucuresti  dublin  \
# Agricultural + Semi-natural areas + Wetlands             1478    3333
# Airports                                                  433      19
# Fast transit roads and associated land                      6     604
# Forests                                                  1285    2527
# Green urban areas                                         585    1374
# Industrial, commercial, public, military and pr...       1570    2244
# Low Density Urban Fabric                                    4    3953
# Other roads and associated land                           975       1
# Sports and leisure facilities                             183    1647
# Water bodies                                             1307    1335
# city total                                               7826   17037
#
# city                                                tallinn  class total
# Agricultural + Semi-natural areas + Wetlands           2959        22706
# Airports                                                  2         1520
# Fast transit roads and associated land                    0         3092
# Forests                                                2550        18003
# Green urban areas                                       805         6316
# Industrial, commercial, public, military and pr...     1487        14065
# Low Density Urban Fabric                               2551        20992
# Other roads and associated land                        1233         6246
# Sports and leisure facilities                           344         6377
# Water bodies                                           1353         6859
# city total                                            13284       106176

# %%
stats_valid
# Out:
# city                                                athina  barcelona  berlin  \
# Agricultural + Semi-natural areas + Wetlands          2927       1411    1027
# Airports                                                27        165     130
# Fast transit roads and associated land                  16         80      22
# Forests                                                261       1038     846
# Green urban areas                                      316        163     698
# Industrial, commercial, public, military and pr...     913        866    1841
# Low Density Urban Fabric                               478        374    1373
# Other roads and associated land                         93         96      36
# Sports and leisure facilities                          145        185     778
# Water bodies                                            46         35     256
# total-city                                            5222       4413    7007
#
# city                                                bucuresti  dublin  \
# Agricultural + Semi-natural areas + Wetlands             4962    2926
# Airports                                                   40     116
# Fast transit roads and associated land                      0      19
# Forests                                                   493     246
# Green urban areas                                         178     476
# Industrial, commercial, public, military and pr...       1211     982
# Low Density Urban Fabric                                    0     695
# Other roads and associated land                             3      18
# Sports and leisure facilities                              58     622
# Water bodies                                              255      66
# total-city                                               7200    6166
#
# city                                                tallinn  total-class
# Agricultural + Semi-natural areas + Wetlands           2287        15540
# Airports                                                 37          515
# Fast transit roads and associated land                    0          137
# Forests                                                2053         4937
# Green urban areas                                       235         2066
# Industrial, commercial, public, military and pr...      584         6397
# Low Density Urban Fabric                                530         3450
# Other roads and associated land                          22          268
# Sports and leisure facilities                            44         1832
# Water bodies                                            301          959
# total-city                                             6093        36101

# %% [markdown]
# ### Split into train & test

# %%
FRAC_TRAIN = 0.8

def split_train_test(my_files_df, frac_train=0.8, save_prefix=""):

    train_df = my_files_df.sample(int(len(my_files_df) * frac_train))
    test_df  = my_files_df[~my_files_df.index.isin(train_df.index)]

    print "Train: %d; Test: %d"%(len(train_df), len(test_df))

    train_df.to_csv("%strain.csv"%save_prefix, index=False)
    test_df.to_csv("%stest.csv"%save_prefix, index=False)

    return train_df, test_df

# %%
mycities = ["tallinn"] #, "berlin", "bucuresti", "tallinn", "athina", "dublin"]
my_files_df = files_df[files_df['city'].isin(mycities)]

train_df, test_df = split_train_test(my_files_df, frac_train=0.8)
# Out:
# Train: 15501; Test: 3876

# %%
train_df['class'].value_counts()
# Out:
# Agricultural + Semi-natural areas + Wetlands                  4211
# Forests                                                       3671
# Low Density Urban Fabric                                      2468
# Industrial, commercial, public, military and private units    1672
# Water bodies                                                  1326
# Other roads and associated land                               1001
# Green urban areas                                              809
# Sports and leisure facilities                                  309
# Airports                                                        34
# Name: class, dtype: int64

# %%
test_df['class'].value_counts()
# Out:
# Agricultural + Semi-natural areas + Wetlands                  1035
# Forests                                                        932
# Low Density Urban Fabric                                       613
# Industrial, commercial, public, military and private units     399
# Water bodies                                                   328
# Other roads and associated land                                254
# Green urban areas                                              231
# Sports and leisure facilities                                   79
# Airports                                                         5
# Name: class, dtype: int64

# %% [markdown]
# ### Set up batching
#
# The data is stored in folders in the format "/city/class-name/city_zoom_lat_lon.jpg". It's not feasible to try to separate the data into train/test beforehand, this should be done via files for train/test with file paths when training the model.

# %%
BATCH_SIZE = 100

# Generator for preprocessing images for data augmentation

from keras.preprocessing.image import ImageDataGenerator

# this is the augmentation configuration we will use for training
train_augmenter = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.10,
        zoom_range=[1,1.2],
        vertical_flip=True,
        rotation_range=15,
        horizontal_flip=True)

test_augmenter = ImageDataGenerator(rescale=1./255)

# %%
tr_gen = ku.generator_from_file("train.csv", \
                                      image_generator=train_augmenter, \
                                      class_dict = class2label,\
                                      balance = 1,
                                      #downsample=2,
                                      new_img_shape=(224,224), 
                                      batch_size=BATCH_SIZE)
ts_gen = ku.generator_from_file("test.csv", \
                                      image_generator=test_augmenter, \
                                      class_dict = class2label,\
                                      balance = 1,
                                      #downsample=2,
                                      new_img_shape=(224,224), 
                                      batch_size=BATCH_SIZE)
i = 0
for X, y in tr_gen:
    print (X.min(), X.max(), X.sum(), X.dtype), X.shape, y.argmax(1).sum()
    i += 1
    if i > 5:
        break
# Out:
# (0.0, 1.0, 10262771.36474693, dtype('float64')) (100, 224, 224, 3) 510
# (0.0, 1.0, 10001746.544811463, dtype('float64')) (100, 224, 224, 3) 459
# (0.0, 1.0, 10363371.306929858, dtype('float64')) (100, 224, 224, 3) 505
# (0.0, 1.0, 9921703.8791364431, dtype('float64')) (100, 224, 224, 3) 496
# (0.0, 1.0, 9897016.649526177, dtype('float64')) (100, 224, 224, 3) 528
# (0.0, 1.0, 10349625.847625632, dtype('float64')) (100, 224, 224, 3) 498

# %%
plt.imshow(X[20,:,:,:])
plt.title(label2class[y[20].argmax()])

# %% [markdown]
# # Define architectures
#
# This uses models previously trained on the DeepSat benchmark.

# %% [markdown]
# #### VGG16 model pre-trained on DeepSat data

# %%
from vgg16 import vgg16
from keras.layers import Dense, Flatten
from keras.models import Model, Sequential

def setup_vgg16(n_classes, model_file):
    # load model and weights
    model = keras.models.load_model(model_file)

    # there's a bug in how Keras handles popping layers for net surgery
    # even if the last layer is popped, the model still believes its output shape is the old one
    # see https://github.com/fchollet/keras/issues/2371
    model.layers.pop() # Get rid of the classification layer
    model.outputs = [model.layers[-1].output]
    model.output_layers = [model.layers[-1]] # added this line in addition to zo7 solution
    model.layers[-1].outbound_nodes = []

    # add new top model for classification over Urban Atlas classes
    top_model = Dense(n_classes, input_shape=model.layers[-1].output_shape[1:], 
                  activation='softmax', name="dense8_new")
    model.add(top_model)
    
    return model

model_file_vgg16 = "../deepsat-experiments/vgg16-deepsat-imagenet-best-checkpoint.h5"

# %% [markdown]
# #### Resnet-50

# %%
from keras.layers import Dense

def setup_resnet50(n_classes, model_file):

    model = keras.models.load_model(model_file)

    model.layers.pop() # Get rid of the classification layer
    model.outputs = [model.layers[-1].output]
    model.output_layers = [model.layers[-1]] # added this line in addition to zo7 solution
    model.layers[-1].outbound_nodes = []

    newClassificationLayer = Dense(N_CLASSES, activation='softmax')(model.layers[-1].output)
    model = Model(input=model.input, output=newClassificationLayer)
    
    return model

model_file_resnet50 = "../deepsat-experiments/resnet-deepsat-imagenet-best-checkpoint.h5"

# %% [markdown]
# # Define training protocol

# %%
import re

def fn_get_acc(filename):
    reg = r"-(\d.+)-"
    match = re.search(reg, filename)
    return float(filename[match.start():match.end()].replace("-",""))

# %%
from keras.optimizers import SGD, RMSprop, Adadelta, Adagrad, Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, TensorBoard

GPUS = [0,1,2,3]
BASE_LR = 0.1
LR_DECAY_PER_EPOCH = 2.0 #1.1

def train_cycle(model, train_generator, test_generator, fix_base=True, save_prefix="", nb_epochs=50):
    
    # control whether to train on 
    trainable_layers = [l.name for l in model.layers if len(l.get_weights())>0 ]
    for l in model.layers:
        l.trainable = (not fix_base) or (l.name == trainable_layers[-1])

    # this uses the TensorFlow backend to spread computation on multiple GPUs
    model_gpu = make_parallel(model, GPUS)

    # compile model
    model_gpu.compile(loss='categorical_crossentropy', \
                  metrics=['accuracy', 'precision', 'recall'],\
                  optimizer=Adadelta(lr=BASE_LR))

    # Logs to TensorBoard, new one for each run
    log_path_tensorboard = "./logs/"
    now = time.strftime("%c")
    tensorboard_callback_fn = TensorBoard(log_dir=log_path_tensorboard + now + "-" + save_prefix, \
                                    histogram_freq=0, \
                                    write_graph=True, \
                                    write_images=False)

    
    # callback to checkpoint best model
    ckpt_file = "%s-{val_acc:.2f}-checkpoint.h5"%save_prefix
    model_checkpoint_callback = ModelCheckpoint(ckpt_file, monitor='val_acc', \
                                                verbose=1, save_best_only=True, mode='max')

    # callback for a custom learning rate decay schedule

    lr_scheduler = lambda epoch: BASE_LR * LR_DECAY_PER_EPOCH**(-(epoch/10))
    lr_decay_callback = keras.callbacks.LearningRateScheduler(lr_scheduler)

    # early stopping callback
    earlystopping_callback = keras.callbacks.EarlyStopping(monitor='val_acc', \
                                                           min_delta=1e-4, \
                                                           patience=10, verbose=0, mode='auto')
    lr_reducer_callback = ReduceLROnPlateau(monitor='val_loss', \
                                            factor=np.sqrt(0.1), \
                                            cooldown=0, patience=5, \
                                            min_lr=0.5e-6)

    # train model
    history = model_gpu.fit_generator(
                train_generator,
                samples_per_epoch=2000,
                class_weight=class_weights,
                nb_epoch=nb_epochs,
                validation_data=test_generator,
                callbacks = [tensorboard_callback_fn, lr_decay_callback, \
                             model_checkpoint_callback, 
                             earlystopping_callback, lr_reducer_callback],
                nb_val_samples=1000)
    
    # return checkpoint of maximum validation accuracy
    model_files = glob.glob("%s-*-checkpoint.h5"%save_prefix)
    checkpoints_dict = {f:fn_get_acc(f) for f in model_files}
    best_checkpoint_file = checkpoints_dict.keys()[checkpoints_dict.values().index(max(checkpoints_dict.values()))]
    return max(history.history['val_acc']), best_checkpoint_file

# %%
# Keras won't release GPU memory, so training multiple models within a loop might crash.
# This is a fix that runs each training cycle in its own OS process using the multiprocessing module.
# See via https://github.com/fchollet/keras/issues/2689

from multiprocessing import Process, Queue

def run_in_separate_process(method, args):
    def queue_wrapper(q, params):
        r = method(*params)
        q.put(r)

    q = Queue()
    p = Process(target=queue_wrapper, args=(q, args))
    p.start()
    return_val = q.get()
    p.join()
    return return_val

# another solution is as follows:

# from keras import backend as K
# K.clear_session()

# %%
K.clear_session()

# %%
# model = setup_resnet50(N_CLASSES, model_file_resnet50)    

# # train using initial weights, only train top layer
# best_acc, best_checkpoint = train_cycle(model, tr_gen, ts_gen, fix_base=True, nb_epochs=30,\
#                                         save_prefix="%s-urbanatlas-%s"%("resnet50", "+".join(mycities)))

# K.clear_session()

# %% [markdown]
# # Loop through experiments

# %%
# set up experiments

cities = ["athina", "berlin", "bucuresti", "tallinn", "barcelona", "dublin"]
mycities = [[x] for x in cities] + [cities]

architectures = [("resnet50", setup_resnet50, model_file_resnet50),
                 ("vgg16", setup_vgg16, model_file_vgg16)]

# %%
val_acc_dict = {}

# %%
from keras.optimizers import SGD, RMSprop, Adadelta, Adagrad, Adam
import time

for cur_cities in mycities:
    
    # load data, set up classes
    
    my_files_df = files_df[files_df['city'].isin(cur_cities)]
    save_prefix = "+".join(cur_cities)
    
    # split into test & train
    
    train_df = my_files_df.sample(int(len(my_files_df) * FRAC_TRAIN))
    train_csv= "%s-train.csv"%save_prefix
    train_df.to_csv(train_csv, index=False)

    test_df  = my_files_df[~my_files_df.index.isin(train_df.index)]
    test_csv = "%s-test.csv"%save_prefix
    test_df.to_csv(test_csv, index=False)
    print "%s | train: %d | test: %d"%("+".join(cur_cities), len(train_df), len(test_df))

    # define test & train generators
    
    train_generator = ku.generator_from_file(train_csv, \
                                      image_generator=train_augmenter, \
                                      class_dict = class2label,\
                                      balance = 1,
                                      #downsample=2,
                                      new_img_shape=(224,224), 
                                      batch_size=BATCH_SIZE)
    test_generator  = ku.generator_from_file(test_csv, \
                                          image_generator=test_augmenter, \
                                          balance = 1,
                                          #downsample=2,
                                          class_dict = class2label,\
                                          new_img_shape=(224,224), 
                                          batch_size=BATCH_SIZE)
    # train architectures 
    
    for architecture, fn_setup_architecture, model_file in architectures:
        
        existing_checkpoints = glob.glob("*checkpoint.h5")
        existing_checkpoints = np.unique([f.split("-")[0] + f.split("-")[2] for f in existing_checkpoints])
        if architecture + save_prefix in existing_checkpoints:
            print (architecture, save_prefix), "already computed!"
            continue
        
        # set up model
        K.clear_session()
        model = fn_setup_architecture(N_CLASSES, model_file)    
        
        # train using initial weights, only train top layer for a smaller number of epochs
        # this is because the random initialization might propagate errors down the network
        print "%s | %s | training top layer" % (save_prefix, architecture) 
        best_acc1, best_checkpoint = train_cycle(model, train_generator, test_generator, fix_base=True, nb_epochs=20,\
                                                save_prefix="%s-urbanatlas-%s"%(architecture, save_prefix))
        clear_output(wait=True)
        K.clear_session()
        
        # further train all layers in the network
        print "%s | %s | training all layers" % (save_prefix, architecture) 
        model = keras.models.load_model(best_checkpoint)
        best_acc2, best_checkpoint = train_cycle(model, train_generator, test_generator, fix_base=False, \
                                                save_prefix="%s-urbanatlas-%s"%(architecture, save_prefix))        
        clear_output(wait=True)
        K.clear_session()
        
        # further train all layers in the network starting from best checkpoint
        # looks like this improves the accuracy slightly in experiments
        print "%s | %s | further training" % (save_prefix, architecture) 
        model = keras.models.load_model(best_checkpoint)
        best_acc3, best_checkpoint = train_cycle(model, train_generator, test_generator, fix_base=False, \
                                                save_prefix="%s-urbanatlas-%s"%(architecture, save_prefix))
        clear_output(wait=True)
        K.clear_session()        
        
        val_acc_dict[(save_prefix, architecture)] = (best_acc1, best_acc2, best_acc3)
# Out:
# athina+berlin+bucuresti+tallinn+barcelona+dublin | resnet50 | further training
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:618 in set_model.: merge_all_summaries (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge_all.
# Epoch 1/50
# Epoch 00000: val_acc improved from -inf to 0.64800, saving model to resnet50-urbanatlas-athina+berlin+bucuresti+tallinn+barcelona+dublin-0.65-checkpoint.h5
# 2000/2000 [==============================] - 53s - loss: 1.1046 - acc: 0.6260 - precision: 0.7702 - recall: 0.4870 - val_loss: 1.0369 - val_acc: 0.6480 - val_precision: 0.7621 - val_recall: 0.5510
# Epoch 2/50
# Epoch 00001: val_acc improved from 0.64800 to 0.66100, saving model to resnet50-urbanatlas-athina+berlin+bucuresti+tallinn+barcelona+dublin-0.66-checkpoint.h5
# 2000/2000 [==============================] - 40s - loss: 1.1256 - acc: 0.6215 - precision: 0.7656 - recall: 0.4805 - val_loss: 1.0397 - val_acc: 0.6610 - val_precision: 0.7639 - val_recall: 0.5390
# Epoch 3/50
# Epoch 00002: val_acc improved from 0.66100 to 0.67000, saving model to resnet50-urbanatlas-athina+berlin+bucuresti+tallinn+barcelona+dublin-0.67-checkpoint.h5
# 2000/2000 [==============================] - 40s - loss: 1.0758 - acc: 0.6420 - precision: 0.7664 - recall: 0.5020 - val_loss: 1.0279 - val_acc: 0.6700 - val_precision: 0.7472 - val_recall: 0.5580
# Epoch 4/50
# Epoch 00003: val_acc did not improve
# 2000/2000 [==============================] - 39s - loss: 1.1074 - acc: 0.6255 - precision: 0.7647 - recall: 0.4830 - val_loss: 1.0563 - val_acc: 0.6440 - val_precision: 0.7613 - val_recall: 0.5230
# Epoch 5/50
# Epoch 00004: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 1.0367 - acc: 0.6485 - precision: 0.7783 - recall: 0.5075 - val_loss: 0.9679 - val_acc: 0.6660 - val_precision: 0.7809 - val_recall: 0.5550
# Epoch 6/50
# Epoch 00005: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 1.0449 - acc: 0.6490 - precision: 0.7973 - recall: 0.4975 - val_loss: 1.0111 - val_acc: 0.6600 - val_precision: 0.7716 - val_recall: 0.5760
# Epoch 7/50
# Epoch 00006: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 1.0771 - acc: 0.6555 - precision: 0.7780 - recall: 0.5055 - val_loss: 1.0471 - val_acc: 0.6350 - val_precision: 0.7342 - val_recall: 0.5380
# Epoch 8/50
# Epoch 00007: val_acc improved from 0.67000 to 0.67300, saving model to resnet50-urbanatlas-athina+berlin+bucuresti+tallinn+barcelona+dublin-0.67-checkpoint.h5
# 2000/2000 [==============================] - 40s - loss: 1.0428 - acc: 0.6540 - precision: 0.7770 - recall: 0.5305 - val_loss: 0.9930 - val_acc: 0.6730 - val_precision: 0.7693 - val_recall: 0.5750
# Epoch 9/50
# Epoch 00008: val_acc improved from 0.67300 to 0.69100, saving model to resnet50-urbanatlas-athina+berlin+bucuresti+tallinn+barcelona+dublin-0.69-checkpoint.h5
# 2000/2000 [==============================] - 40s - loss: 1.0510 - acc: 0.6490 - precision: 0.7733 - recall: 0.5160 - val_loss: 0.9417 - val_acc: 0.6910 - val_precision: 0.7800 - val_recall: 0.5740
# Epoch 10/50
# Epoch 00009: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 1.0159 - acc: 0.6630 - precision: 0.7841 - recall: 0.5370 - val_loss: 1.0545 - val_acc: 0.6550 - val_precision: 0.7546 - val_recall: 0.5590
# Epoch 11/50
# Epoch 00010: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 1.0148 - acc: 0.6560 - precision: 0.7788 - recall: 0.5235 - val_loss: 0.9426 - val_acc: 0.6730 - val_precision: 0.7693 - val_recall: 0.5870
# Epoch 12/50
# Epoch 00011: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9537 - acc: 0.6785 - precision: 0.8106 - recall: 0.5655 - val_loss: 0.9430 - val_acc: 0.6750 - val_precision: 0.7695 - val_recall: 0.5910
# Epoch 13/50
# Epoch 00012: val_acc improved from 0.69100 to 0.70900, saving model to resnet50-urbanatlas-athina+berlin+bucuresti+tallinn+barcelona+dublin-0.71-checkpoint.h5
# 2000/2000 [==============================] - 40s - loss: 1.0193 - acc: 0.6625 - precision: 0.7886 - recall: 0.5425 - val_loss: 0.9440 - val_acc: 0.7090 - val_precision: 0.7898 - val_recall: 0.6160
# Epoch 14/50
# Epoch 00013: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9659 - acc: 0.6690 - precision: 0.7918 - recall: 0.5535 - val_loss: 1.0001 - val_acc: 0.6820 - val_precision: 0.7801 - val_recall: 0.5990
# Epoch 15/50
# Epoch 00014: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 1.0082 - acc: 0.6605 - precision: 0.7833 - recall: 0.5475 - val_loss: 0.9822 - val_acc: 0.6800 - val_precision: 0.7722 - val_recall: 0.5900
# Epoch 16/50
# Epoch 00015: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 1.0059 - acc: 0.6645 - precision: 0.7893 - recall: 0.5425 - val_loss: 0.9106 - val_acc: 0.6830 - val_precision: 0.7708 - val_recall: 0.6010
# Epoch 17/50
# Epoch 00016: val_acc did not improve
# 2000/2000 [==============================] - 39s - loss: 0.9616 - acc: 0.6750 - precision: 0.7957 - recall: 0.5425 - val_loss: 0.9718 - val_acc: 0.6980 - val_precision: 0.7881 - val_recall: 0.6140
# Epoch 18/50
# Epoch 00017: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9886 - acc: 0.6700 - precision: 0.7934 - recall: 0.5530 - val_loss: 0.8950 - val_acc: 0.6900 - val_precision: 0.7884 - val_recall: 0.6090
# Epoch 19/50
# Epoch 00018: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9783 - acc: 0.6730 - precision: 0.8048 - recall: 0.5410 - val_loss: 0.9170 - val_acc: 0.6960 - val_precision: 0.7974 - val_recall: 0.6120
# Epoch 20/50
# Epoch 00019: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9661 - acc: 0.6805 - precision: 0.7968 - recall: 0.5595 - val_loss: 0.9346 - val_acc: 0.6810 - val_precision: 0.7735 - val_recall: 0.5850
# Epoch 21/50
# Epoch 00020: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9662 - acc: 0.6790 - precision: 0.8010 - recall: 0.5575 - val_loss: 0.9114 - val_acc: 0.7060 - val_precision: 0.7769 - val_recall: 0.6240
# Epoch 22/50
# Epoch 00021: val_acc improved from 0.70900 to 0.71200, saving model to resnet50-urbanatlas-athina+berlin+bucuresti+tallinn+barcelona+dublin-0.71-checkpoint.h5
# 2000/2000 [==============================] - 40s - loss: 0.9834 - acc: 0.6630 - precision: 0.7842 - recall: 0.5445 - val_loss: 0.9069 - val_acc: 0.7120 - val_precision: 0.7961 - val_recall: 0.6270
# Epoch 23/50
# Epoch 00022: val_acc did not improve
# 2000/2000 [==============================] - 39s - loss: 0.9813 - acc: 0.6735 - precision: 0.8002 - recall: 0.5600 - val_loss: 0.9181 - val_acc: 0.7100 - val_precision: 0.8088 - val_recall: 0.6270
# Epoch 24/50
# Epoch 00023: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9743 - acc: 0.6795 - precision: 0.8056 - recall: 0.5525 - val_loss: 0.9048 - val_acc: 0.7010 - val_precision: 0.7999 - val_recall: 0.6400
# Epoch 25/50
# Epoch 00024: val_acc improved from 0.71200 to 0.71300, saving model to resnet50-urbanatlas-athina+berlin+bucuresti+tallinn+barcelona+dublin-0.71-checkpoint.h5
# 2000/2000 [==============================] - 40s - loss: 0.9664 - acc: 0.6700 - precision: 0.7978 - recall: 0.5475 - val_loss: 0.8740 - val_acc: 0.7130 - val_precision: 0.7990 - val_recall: 0.6300
# Epoch 26/50
# Epoch 00025: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9960 - acc: 0.6635 - precision: 0.7889 - recall: 0.5415 - val_loss: 0.9707 - val_acc: 0.6710 - val_precision: 0.7739 - val_recall: 0.5930
# Epoch 27/50
# Epoch 00026: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9347 - acc: 0.6880 - precision: 0.8134 - recall: 0.5615 - val_loss: 0.9156 - val_acc: 0.7000 - val_precision: 0.8049 - val_recall: 0.6080
# Epoch 28/50
# Epoch 00027: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9787 - acc: 0.6775 - precision: 0.7914 - recall: 0.5505 - val_loss: 0.9275 - val_acc: 0.6950 - val_precision: 0.7875 - val_recall: 0.5980
# Epoch 29/50
# Epoch 00028: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9699 - acc: 0.6700 - precision: 0.7984 - recall: 0.5500 - val_loss: 0.9022 - val_acc: 0.6930 - val_precision: 0.7837 - val_recall: 0.6130
# Epoch 30/50
# Epoch 00029: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9426 - acc: 0.6840 - precision: 0.8001 - recall: 0.5655 - val_loss: 0.8638 - val_acc: 0.7070 - val_precision: 0.7999 - val_recall: 0.6120
# Epoch 31/50
# Epoch 00030: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9610 - acc: 0.6815 - precision: 0.8093 - recall: 0.5640 - val_loss: 0.8635 - val_acc: 0.7080 - val_precision: 0.7890 - val_recall: 0.6320
# Epoch 32/50
# Epoch 00031: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9013 - acc: 0.6945 - precision: 0.8116 - recall: 0.5745 - val_loss: 0.9473 - val_acc: 0.6720 - val_precision: 0.7884 - val_recall: 0.5990
# Epoch 33/50
# Epoch 00032: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9873 - acc: 0.6640 - precision: 0.7973 - recall: 0.5480 - val_loss: 0.9527 - val_acc: 0.6890 - val_precision: 0.7858 - val_recall: 0.6130
# Epoch 34/50
# Epoch 00033: val_acc did not improve
# 2000/2000 [==============================] - 40s - loss: 0.9340 - acc: 0.6890 - precision: 0.8197 - recall: 0.5790 - val_loss: 0.9602 - val_acc: 0.6830 - val_precision: 0.7834 - val_recall: 0.5930
# Epoch 35/50
# Epoch 00034: val_acc improved from 0.71300 to 0.72700, saving model to resnet50-urbanatlas-athina+berlin+bucuresti+tallinn+barcelona+dublin-0.73-checkpoint.h5
# 2000/2000 [==============================] - 40s - loss: 0.9292 - acc: 0.6915 - precision: 0.8181 - recall: 0.5630 - val_loss: 0.8423 - val_acc: 0.7270 - val_precision: 0.8233 - val_recall: 0.6460
# Epoch 36/50
# Epoch 00035: val_acc did not improve
# 2000/2000 [==============================] - 39s - loss: 0.9260 - acc: 0.6945 - precision: 0.8240 - recall: 0.5720 - val_loss: 0.9487 - val_acc: 0.6690 - val_precision: 0.7679 - val_recall: 0.6060
# Epoch 37/50
# Epoch 00036: val_acc did not improve
# 2000/2000 [==============================] - 39s - loss: 0.9725 - acc: 0.6750 - precision: 0.7901 - recall: 0.5595 - val_loss: 0.9812 - val_acc: 0.6660 - val_precision: 0.7586 - val_recall: 0.5760
# Epoch 38/50
# Epoch 00037: val_acc did not improve
# 2000/2000 [==============================] - 43s - loss: 0.9326 - acc: 0.6885 - precision: 0.8049 - recall: 0.5720 - val_loss: 0.8954 - val_acc: 0.7030 - val_precision: 0.8100 - val_recall: 0.6070
# Epoch 39/50
# 1900/2000 [===========================>..] - ETA: 1s - loss: 0.9601 - acc: 0.6711 - precision: 0.7940 - recall: 0.5500
