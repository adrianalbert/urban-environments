# %%
# Import several packages that will be used throughout

# numeric packages
import numpy as np
import scipy
import scipy.io
import pandas as pd
import h5py

# filesystem and OS
import sys, os, time
import glob

# plotting
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid", {'axes.grid' : False})
from IPython.display import clear_output

import warnings
warnings.filterwarnings('ignore')

# these magics ensure that external modules that are modified are also automatically reloaded
# %load_ext autoreload
# %autoreload 2

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
sys.path.append("/home/adalbert/nbserver/satsense/keras-utils/")
sys.path.append("/home/adalbert/nbserver/satsense/keras-models/")
sys.path.append("/home/adalbert/nbserver/keras/keras/utils/")

from multi_gpu import make_parallel
import keras_utils as ku

# %%
workdir = "/home/adalbert/nbserver/tf-workspace/deepsat-experiments/"
os.chdir(workdir)

# %% [markdown]
# # Import data and set up batching

# %% [markdown]
# ### Set up batching

# %%
BATCH_SIZE = 100

train_dir = "/home/adalbert/data/DeepSat/img/train/"
test_dir = "/home/adalbert/data/DeepSat/img/test/"

# %%
# Generator for preprocessing images for data augmentation

from keras.preprocessing.image import ImageDataGenerator

def apply_mean(image_data_generator):
    """Subtracts the VGG dataset mean"""
    image_data_generator.mean = np.array([123.68, 116.779, 103.939], dtype=np.float32).reshape((3, 1, 1))

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.1,
        zoom_range=[1,1.2],
        vertical_flip=True,
        rotation_range=15,
        horizontal_flip=True)
apply_mean(train_datagen)


# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1./255)
apply_mean(test_datagen)

train_generator = train_datagen.flow_from_directory(train_dir, \
                                         batch_size=BATCH_SIZE,
                                         target_size=(224,224),
                                         shuffle=True)
    
# this is a similar generator, for validation data
test_generator = test_datagen.flow_from_directory(test_dir, \
                                         batch_size=BATCH_SIZE,
                                         target_size=(224,224),
                                         shuffle=True)

# get class labels
class2ind = train_generator.class_indices
ind2class = {v:k for k,v in class2ind.iteritems()}

N_CLASSES = len(ind2class)
# Out:
# Found 324000 images belonging to 6 classes.
# Found 81000 images belonging to 6 classes.

# %%
for Xbatch, ybatch in train_generator:
    print Xbatch.shape, ybatch.shape, Xbatch.min(), Xbatch.max()
    break
# Out:
# (100, 224, 224, 3) (100, 6) 0.0 1.0

# %% [markdown]
# # Define architectures to use
# Load weights from model pretrained on ImageNet

# %% [markdown]
# #### VGG-16, pre-trained on ImageNet
# Note that the weights are trained on BGR data for this architecture (probably following Caffe's convention). It turns out that they're a good enough starting point even if using RGB images.

# %%
from vgg16 import vgg16

# build the convolutional base of the VGG16 network
model = vgg16(n_classes=N_CLASSES, input_shape=(224,224,3), fcn=False)

weights_file = "../vgg16_weights.h5"
model = ku.load_weights_into_model(model, weights_file, transpose_conv=True, 
                        layers_to_skip=["dense8"])

freeze_layers = [] #['conv1', 'conv2']
for l in model.layers:
    l.trainable = len([x for x in freeze_layers if x in l.name])==0 and \
                    len(l.get_weights())>0

for l in model.layers:
    print l.name, [x.sum() for x in l.get_weights()], l.trainable

# %% [markdown]
# #### ResNet initialized with ImageNet weights

# %%
sys.path.append("/home/adalbert/nbserver/DeepGold/deep-learning-models/")

from keras.layers import Flatten, Dense
from keras.models import Model
from resnet50 import ResNet50
from keras.preprocessing import image
from imagenet_utils import preprocess_input, decode_predictions

model = ResNet50(weights='imagenet', include_top=True)

model.layers.pop() # Get rid of the classification layer
model.outputs = [model.layers[-1].output]
model.output_layers = [model.layers[-1]] # added this line in addition to zo7 solution
model.layers[-1].outbound_nodes = []

newClassificationLayer = Dense(N_CLASSES, activation='softmax')(model.layers[-1].output)
model = Model(input=model.input, output=newClassificationLayer)
# Out:
# K.image_dim_ordering: tf

# %% [markdown]
# #### Load previously-saved model

# %%
# load model from checkpoint
model_file = "vgg16-deepsat-best-checkpoint.h5"

# with tf.device('/cpu:0'):
# load model and weights
model = keras.models.load_model(model_file)

# %% [markdown]
# Spread model computation on multiple GPUs

# %%
GPUS = [0,1,2,3]

# this uses the TensorFlow backend to spread computation on multiple GPUs
model_gpu = make_parallel(model, GPUS)

# %% [markdown]
# # Fine-tune model

# %% [markdown]
# Define model behavior with callbacks and compile

# %%
from keras.callbacks import ModelCheckpoint

# callback for a custom learning rate decay schedule

LR_DECAY_PER_EPOCH = 2.0 #1.1
BASE_LR = 1

lr_scheduler = lambda epoch: BASE_LR * LR_DECAY_PER_EPOCH**(-(epoch/10))
lr_decay_callback = keras.callbacks.LearningRateScheduler(lr_scheduler)

# callback to checkpoint best model
model_checkpoint_callback = ModelCheckpoint("resnet-deepsat-imagenet-best-checkpoint.h5", monitor='val_acc', \
                                      verbose=1, save_best_only=True, mode='max')

# compile model
from keras.optimizers import SGD, RMSprop, Adadelta, Adagrad, Adam
model_gpu.compile(loss='categorical_crossentropy', \
              metrics=['accuracy'],\
              optimizer=Adadelta(lr=BASE_LR))

# %% [markdown]
# Compile and train model

# %%
# Logs to TensorBoard, new one for each run

log_path_tensorboard = "./logs/"

from keras.callbacks import TensorBoard
import time

now = time.strftime("%c")
tensorboard_callback_fn = TensorBoard(log_dir=log_path_tensorboard + now, \
                                histogram_freq=1, \
                                write_graph=True, \
                                write_images=False)

# Train model

history = model_gpu.fit_generator(
            train_generator,
            samples_per_epoch=2000,
            nb_epoch=50,
            validation_data=test_generator,
            callbacks = [tensorboard_callback_fn, lr_decay_callback, \
                         model_checkpoint_callback],
            nb_val_samples=1000)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:612 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:612 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:612 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:612 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:612 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# ...
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:588 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:612 in set_model.: histogram_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.histogram. Note that tf.summary.histogram uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on their scope.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/callbacks.py:618 in set_model.: merge_all_summaries (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge_all.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/logging_ops.py:264 in merge_all_summaries.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# Epoch 1/50
# Epoch 00000: val_acc improved from -inf to 0.09300, saving model to resnet-deepsat-imagenet-best-checkpoint.h5
# 2000/2000 [==============================] - 36s - loss: 0.4762 - acc: 0.8675 - val_loss: 4.3841 - val_acc: 0.0930
# Epoch 2/50
# Epoch 00001: val_acc improved from 0.09300 to 0.54400, saving model to resnet-deepsat-imagenet-best-checkpoint.h5
# 2000/2000 [==============================] - 30s - loss: 0.1577 - acc: 0.9385 - val_loss: 1.7630 - val_acc: 0.5440
# Epoch 3/50
# Epoch 00002: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.1499 - acc: 0.9475 - val_loss: 1.5979 - val_acc: 0.5410
# Epoch 4/50
# Epoch 00003: val_acc improved from 0.54400 to 0.59300, saving model to resnet-deepsat-imagenet-best-checkpoint.h5
# 2000/2000 [==============================] - 30s - loss: 0.1129 - acc: 0.9680 - val_loss: 1.3193 - val_acc: 0.5930
# Epoch 5/50
# Epoch 00004: val_acc improved from 0.59300 to 0.73100, saving model to resnet-deepsat-imagenet-best-checkpoint.h5
# 2000/2000 [==============================] - 30s - loss: 0.1275 - acc: 0.9565 - val_loss: 0.6651 - val_acc: 0.7310
# Epoch 6/50
# Epoch 00005: val_acc improved from 0.73100 to 0.94800, saving model to resnet-deepsat-imagenet-best-checkpoint.h5
# 2000/2000 [==============================] - 30s - loss: 0.1150 - acc: 0.9595 - val_loss: 0.1286 - val_acc: 0.9480
# Epoch 7/50
# Epoch 00006: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.1337 - acc: 0.9515 - val_loss: 0.6526 - val_acc: 0.7490
# Epoch 8/50
# Epoch 00007: val_acc improved from 0.94800 to 0.96100, saving model to resnet-deepsat-imagenet-best-checkpoint.h5
# 2000/2000 [==============================] - 31s - loss: 0.0952 - acc: 0.9645 - val_loss: 0.1041 - val_acc: 0.9610
# Epoch 9/50
# Epoch 00008: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.1007 - acc: 0.9670 - val_loss: 0.1339 - val_acc: 0.9540
# Epoch 10/50
# Epoch 00009: val_acc improved from 0.96100 to 0.98300, saving model to resnet-deepsat-imagenet-best-checkpoint.h5
# 2000/2000 [==============================] - 30s - loss: 0.1058 - acc: 0.9650 - val_loss: 0.0463 - val_acc: 0.9830
# Epoch 11/50
# Epoch 00010: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0660 - acc: 0.9760 - val_loss: 0.0507 - val_acc: 0.9750
# Epoch 12/50
# Epoch 00011: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0527 - acc: 0.9815 - val_loss: 0.0746 - val_acc: 0.9740
# Epoch 13/50
# Epoch 00012: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0633 - acc: 0.9820 - val_loss: 0.0729 - val_acc: 0.9720
# Epoch 14/50
# Epoch 00013: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0633 - acc: 0.9790 - val_loss: 0.0826 - val_acc: 0.9730
# Epoch 15/50
# Epoch 00014: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0600 - acc: 0.9840 - val_loss: 0.0719 - val_acc: 0.9740
# Epoch 16/50
# Epoch 00015: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0720 - acc: 0.9775 - val_loss: 0.0775 - val_acc: 0.9700
# Epoch 17/50
# Epoch 00016: val_acc improved from 0.98300 to 0.98700, saving model to resnet-deepsat-imagenet-best-checkpoint.h5
# 2000/2000 [==============================] - 30s - loss: 0.0606 - acc: 0.9785 - val_loss: 0.0439 - val_acc: 0.9870
# Epoch 18/50
# Epoch 00017: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0441 - acc: 0.9860 - val_loss: 0.0649 - val_acc: 0.9750
# Epoch 19/50
# Epoch 00018: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0626 - acc: 0.9780 - val_loss: 0.0453 - val_acc: 0.9830
# Epoch 20/50
# Epoch 00019: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0681 - acc: 0.9750 - val_loss: 0.0503 - val_acc: 0.9860
# Epoch 21/50
# Epoch 00020: val_acc improved from 0.98700 to 0.98800, saving model to resnet-deepsat-imagenet-best-checkpoint.h5
# 2000/2000 [==============================] - 31s - loss: 0.0484 - acc: 0.9795 - val_loss: 0.0304 - val_acc: 0.9880
# Epoch 22/50
# Epoch 00021: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0423 - acc: 0.9830 - val_loss: 0.0568 - val_acc: 0.9840
# Epoch 23/50
# Epoch 00022: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0482 - acc: 0.9825 - val_loss: 0.0370 - val_acc: 0.9850
# Epoch 24/50
# Epoch 00023: val_acc improved from 0.98800 to 0.99000, saving model to resnet-deepsat-imagenet-best-checkpoint.h5
# 2000/2000 [==============================] - 30s - loss: 0.0441 - acc: 0.9845 - val_loss: 0.0405 - val_acc: 0.9900
# Epoch 25/50
# Epoch 00024: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0517 - acc: 0.9775 - val_loss: 0.0298 - val_acc: 0.9900
# Epoch 26/50
# Epoch 00025: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0507 - acc: 0.9835 - val_loss: 0.0308 - val_acc: 0.9900
# Epoch 27/50
# Epoch 00026: val_acc improved from 0.99000 to 0.99200, saving model to resnet-deepsat-imagenet-best-checkpoint.h5
# 2000/2000 [==============================] - 30s - loss: 0.0417 - acc: 0.9855 - val_loss: 0.0222 - val_acc: 0.9920
# Epoch 28/50
# Epoch 00027: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0443 - acc: 0.9875 - val_loss: 0.0941 - val_acc: 0.9680
# Epoch 29/50
# Epoch 00028: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0415 - acc: 0.9865 - val_loss: 0.0490 - val_acc: 0.9830
# Epoch 30/50
# Epoch 00029: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0395 - acc: 0.9855 - val_loss: 0.0546 - val_acc: 0.9810
# Epoch 31/50
# Epoch 00030: val_acc improved from 0.99200 to 0.99400, saving model to resnet-deepsat-imagenet-best-checkpoint.h5
# 2000/2000 [==============================] - 30s - loss: 0.0366 - acc: 0.9880 - val_loss: 0.0293 - val_acc: 0.9940
# Epoch 32/50
# Epoch 00031: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0371 - acc: 0.9860 - val_loss: 0.0396 - val_acc: 0.9870
# Epoch 33/50
# Epoch 00032: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0438 - acc: 0.9830 - val_loss: 0.0414 - val_acc: 0.9830
# Epoch 34/50
# Epoch 00033: val_acc improved from 0.99400 to 0.99500, saving model to resnet-deepsat-imagenet-best-checkpoint.h5
# 2000/2000 [==============================] - 30s - loss: 0.0433 - acc: 0.9860 - val_loss: 0.0254 - val_acc: 0.9950
# Epoch 35/50
# Epoch 00034: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0412 - acc: 0.9870 - val_loss: 0.0436 - val_acc: 0.9850
# Epoch 36/50
# Epoch 00035: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0376 - acc: 0.9880 - val_loss: 0.0292 - val_acc: 0.9890
# Epoch 37/50
# Epoch 00036: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0211 - acc: 0.9940 - val_loss: 0.0423 - val_acc: 0.9880
# Epoch 38/50
# Epoch 00037: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0305 - acc: 0.9880 - val_loss: 0.0376 - val_acc: 0.9880
# Epoch 39/50
# Epoch 00038: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0317 - acc: 0.9875 - val_loss: 0.0203 - val_acc: 0.9950
# Epoch 40/50
# Epoch 00039: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0429 - acc: 0.9850 - val_loss: 0.0288 - val_acc: 0.9910
# Epoch 41/50
# Epoch 00040: val_acc did not improve
# 2000/2000 [==============================] - 29s - loss: 0.0372 - acc: 0.9900 - val_loss: 0.0286 - val_acc: 0.9910
# Epoch 42/50
# Epoch 00041: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0319 - acc: 0.9885 - val_loss: 0.0244 - val_acc: 0.9920
# Epoch 43/50
# Epoch 00042: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0390 - acc: 0.9890 - val_loss: 0.0366 - val_acc: 0.9880
# Epoch 44/50
# Epoch 00043: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0412 - acc: 0.9845 - val_loss: 0.0281 - val_acc: 0.9940
# Epoch 45/50
# Epoch 00044: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0319 - acc: 0.9875 - val_loss: 0.0345 - val_acc: 0.9850
# Epoch 46/50
# Epoch 00045: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0342 - acc: 0.9915 - val_loss: 0.0325 - val_acc: 0.9900
# Epoch 47/50
# Epoch 00046: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0247 - acc: 0.9925 - val_loss: 0.0161 - val_acc: 0.9940
# Epoch 48/50
# Epoch 00047: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0398 - acc: 0.9865 - val_loss: 0.0211 - val_acc: 0.9940
# Epoch 49/50
# Epoch 00048: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0334 - acc: 0.9900 - val_loss: 0.0315 - val_acc: 0.9950
# Epoch 50/50
# Epoch 00049: val_acc did not improve
# 2000/2000 [==============================] - 30s - loss: 0.0315 - acc: 0.9895 - val_loss: 0.0244 - val_acc: 0.9930

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))
ax[0].plot(history.history['loss'], label="train")
ax[0].plot(history.history['val_loss'], label="test")
ax[0].set_title("Loss", fontsize=14)
ax[0].set_xlabel("Epoch")
ax[0].legend(loc="best")
ax[1].plot(history.history['acc'], label="train")
ax[1].plot(history.history['val_acc'], label="test")
ax[1].set_title("Accuracy", fontsize=14)
ax[1].set_xlabel("Epoch")
ax[1].legend(loc="best")
plt.show()
